# %% [markdown]
# # Diferencia entre Normalizar y Estandarizar

# %% [markdown]
# # Machine Learning
# >

# %%
from IPython.display import Image
Image("Machine Learning.png",width = 500, height = 300)

# %% [markdown]
# # Regularizacion

# %%
from sklearn import datasets
dataset= datasets.load_boston()
dataset.keys()
# Out:
# /Users/jorge/miniconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
# print(dataset.DESCR)

# %%
import pandas as pd

# %%
df_houses= pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
df_houses.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df_houses["target"] = dataset.target

# %%
df_houses.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
from sklearn.ensemble import RandomForestRegressor

from sklearn.tree import plot_tree
model_random_forest = RandomForestRegressor()
from sklearn.tree import export_graphviz
from sklearn.metrics import f1_score,auc,accuracy_score,confusion_matrix,roc_curve,plot_roc_curve,plot_precision_recall_curve,recall_score

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_houses.drop(columns="target"), df_houses.target)

# %%
model_random_forest.fit(X = X_train,y= y_train)
# Out:
# RandomForestRegressor()

# %%
model_random_forest.apply(X=X_train).shape
# Out:
# (379, 100)

# %%
model_random_forest.score(X= X_test, y = y_test)
# Out:
# 0.9016934396877092

# %%
plot_roc_curve(model_random_forest,X= X_test, y = y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [408], in <cell line: 1>()
# ----> 1 plot_roc_curve(model_random_forest,X= X_test, y = y_test)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:88, in deprecated._decorate_fun.<locals>.wrapped(*args, **kwargs)
#      85 @functools.wraps(fun)
#      86 def wrapped(*args, **kwargs):
#      87     warnings.warn(msg, category=FutureWarning)
# ---> 88     return fun(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_plot/roc_curve.py:451, in plot_roc_curve(estimator, X, y, sample_weight, drop_intermediate, response_method, name, ax, pos_label, **kwargs)
#     371 """Plot Receiver operating characteristic (ROC) curve.
#     372
#     373 Extra keyword arguments will be passed to matplotlib's `plot`.
#    (...)
#     447 >>> plt.show()
#     448 """
# ...

# %%
plot_roc_curve(model_random_forest,X= X_test, y = y_test)
accuracy_score(y_true=X_test,y_pred=y_test)
confusion_matrix(y_true=X_test,y_pred=y_test)
# Out:
# /Users/jorge/miniconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [407], in <cell line: 1>()
# ----> 1 plot_roc_curve(model_random_forest,X= X_test, y = y_test)
#       2 accuracy_score(y_true=X_test,y_pred=y_test)
#       3 confusion_matrix(y_true=X_test,y_pred=y_test)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:88, in deprecated._decorate_fun.<locals>.wrapped(*args, **kwargs)
#      85 @functools.wraps(fun)
# ...

# %%
model_random_forest

# %% [markdown]
# # LinearRegression
# >

# %%
from sklearn import datasets

# %%
dataset = datasets.load_boston()
dataset.keys()
# Out:
# /Users/jorge/miniconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
print(dataset["DESCR"])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
dataset["feature_names"]
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
target= dataset["target"]
target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
exploraty = dataset["data"]
exploraty
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
from sklearn.linear_model import LinearRegression

# %%
LinearRegression().__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False}

# %%
id(LinearRegression)
# Out:
# 140412661563344

# %%
hash(id(LinearRegression))
# Out:
# 140412661563344

# %%
hex(id(LinearRegression))
# Out:
# '0x7fb45ed07fd0'

# %%
model_LR = LinearRegression()

# %%
model_LR.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False}

# %%
model_LR.fit(X= exploraty, y = target)
# Out:
# LinearRegression()

# %%
model_LR.coef_
# Out:
# array([-1.08011358e-01,  4.64204584e-02,  2.05586264e-02,  2.68673382e+00,
#        -1.77666112e+01,  3.80986521e+00,  6.92224640e-04, -1.47556685e+00,
#         3.06049479e-01, -1.23345939e-02, -9.52747232e-01,  9.31168327e-03,
#        -5.24758378e-01])

# %%
model_LR.intercept_
# Out:
# 36.459488385089855

# %%
prediccion = model_LR.predict(X=exploraty)

# %%
# Juntar perdiccion y target

prediccion.shape
# Out:
# (506,)

# %%
target.shape
# Out:
# (506,)

# %%
target[0]
# Out:
# 24.0

# %%
prediccion[0]
# Out:
# 30.003843377016814

# %%
list(zip(prediccion,target))[:][0]
# Out:
# (30.003843377016814, 24.0)

# %%
for i_pred, i in list(zip(prediccion,target))[:5]:
    print("Predicción {:.1f} valor real {:}".format(i_pred, i))
# Out:
# Predicción 30.0 valor real 24.0
# Predicción 25.0 valor real 21.6
# Predicción 30.6 valor real 34.7
# Predicción 28.6 valor real 33.4
# Predicción 27.9 valor real 36.2

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(exploraty,columns=dataset["feature_names"])
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df["target"] = target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
df_exploraty = df.drop(columns="target")
df_exploraty
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df_exploraty.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
df_traget = df.drop(df_exploraty.columns, axis=1)

# %%
model_LR.fit(X=df_exploraty, y= df_traget)
# Out:
# LinearRegression()

# %%
df["model_RL"]= model_LR.predict(X=exploraty)
# Out:
# /Users/jorge/miniconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target   model_RL
# 0     15.3  396.90   4.98    24.0  30.003843
# 1     17.8  396.90   9.14    21.6  25.025562
# 2     17.8  392.83   4.03    34.7  30.567597
# 3     18.7  394.63   2.94    33.4  28.607036
# 4     18.7  396.90   5.33    36.2  27.943524

# %%
modol_RL_2 = LinearRegression(fit_intercept=False)

# %%
modol_RL_2.fit(X=exploraty, y=target)
# Out:
# LinearRegression(fit_intercept=False)

# %%
modol_RL_2.__dict__
# Out:
# {'fit_intercept': False,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 13,
#  'coef_': array([-9.28965170e-02,  4.87149552e-02, -4.05997958e-03,  2.85399882e+00,
#         -2.86843637e+00,  5.92814778e+00, -7.26933458e-03, -9.68514157e-01,
#          1.71151128e-01, -9.39621540e-03, -3.92190926e-01,  1.49056102e-02,
#         -4.16304471e-01]),
#  'rank_': 13,
#  'singular_': array([1.25851816e+04, 3.44597406e+03, 6.45757109e+02, 4.02050461e+02,
#         1.58964612e+02, 1.21502936e+02, 9.04652420e+01, 7.79311708e+01,
#         6.50828345e+01, 2.46251803e+01, 1.80945451e+01, 5.51505065e+00,
#         1.48096916e+00]),
#  'intercept_': 0.0}

# %%
model_LR.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 13,
#  'coef_': array([[-1.08011358e-01,  4.64204584e-02,  2.05586264e-02,
#           2.68673382e+00, -1.77666112e+01,  3.80986521e+00,
#           6.92224640e-04, -1.47556685e+00,  3.06049479e-01,
#          -1.23345939e-02, -9.52747232e-01,  9.31168327e-03,
#          -5.24758378e-01]]),
#  'rank_': 13,
#  'singular_': array([3.94960823e+03, 1.77663071e+03, 6.42863748e+02, 3.66982075e+02,
#         1.58634553e+02, 1.18649824e+02, 9.00666968e+01, 6.93635022e+01,
#         4.06575034e+01, 2.44208029e+01, 1.13513722e+01, 5.50905795e+00,
#         1.24197449e+00]),
#  'intercept_': array([36.45948839]),
#  'feature_names_in_': array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#         'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype=object)}

# %%
df["model_RL_2"] = modol_RL_2.predict(X=exploraty)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target   model_RL  model_RL_2
# ...

# %%
LinearRegression(normalize=True).__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False}

# %%
model_RL_normalize=LinearRegression(normalize=True)

# %%
model_RL_normalize.fit(X=exploraty,y = target)
# Out:
# /Users/jorge/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# LinearRegression(normalize=True)

# %%
df["model_RL_normalize"]=model_RL_normalize.predict(X=exploraty)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target   model_RL  model_RL_2  model_RL_normalize
# ...

# %%
import plotly.express as plot

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df.model_RL,y=df.target)
sns.scatterplot(x=df.model_RL_2,y=df.target)
sns.scatterplot(x=df.model_RL_normalize,y=df.target)
# Out:
# <AxesSubplot:xlabel='model_RL', ylabel='target'>

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (10, 10))
sns.regplot(x=df.model_RL, y=df.target,ax=ax)
# Out:
# <AxesSubplot:xlabel='model_RL', ylabel='target'>

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (15, 15))

sns.regplot(x=df.model_RL_2, y=df.target,ax=ax)
sns.regplot(x=df.model_RL_normalize, y=df.target,ax=ax);

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import confusion_matrix

mc = confusion_matrix(y_true=df_traget, y_pred=df_exploraty)
mc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [54], in <cell line: 3>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 3 mc = confusion_matrix(y_true=df_traget, y_pred=df_exploraty)
#       4 mc
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:307, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     222 def confusion_matrix(
#     223     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     224 ):
#     225     """Compute confusion matrix to evaluate the accuracy of a classification.
#     226
#     227     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
# ...

# %%
accuracy_score(y_pred=df_exploraty, y_true=df_traget.to_xarray)

# %% [markdown]
# ## Train test
# >

# %%
from IPython.display import Image
Image("train_test.png",width=900)

# %%
from sklearn.model_selection  import train_test_split

# %%
df_exploraty

# %%
X_train, X_test, y_train, y_test = train_test_split(df_exploraty, df_traget)

# %%
X_train.shape

# %%
X_test.shape

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn import datasets

# %%
dataset = datasets.load_boston()

# %%
type(boston)

# %%
boston.keys()

# %%
exploraty = boston["data"]

# %%
target = boston["target"]

# %% [markdown]
# # Diferencias entre DataSet y DataFrame
# >

# %% [markdown]
# # Underfitting vs Overfitting
# >

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score


def true_fun(X):
    return np.cos(1.5 * np.pi * X)


np.random.seed(0)

n_samples = 30
degrees = [1, 4, 15]

X = np.sort(np.random.rand(n_samples))
y = true_fun(X) + np.random.randn(n_samples) * 0.1

plt.figure(figsize=(14, 5))
for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i + 1)
    plt.setp(ax, xticks=(), yticks=())

    polynomial_features = PolynomialFeatures(degree=degrees[i], include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline(
        [
            ("polynomial_features", polynomial_features),
            ("linear_regression", linear_regression),
        ]
    )
    pipeline.fit(X[:, np.newaxis], y)

    # Evaluate the models using crossvalidation
    scores = cross_val_score(
        pipeline, X[:, np.newaxis], y, scoring="neg_mean_squared_error", cv=10
    )

    X_test = np.linspace(0, 1, 100)
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.scatter(X, y, edgecolor="b", s=20, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
    plt.legend(loc="best")
    plt.title(
        "Degree {}\nMSE = {:.2e}(+/- {:.2e})".format(
            degrees[i], -scores.mean(), scores.std()
        )
    )
plt.show()

# %%
from IPython.display import Image
Image("generalizacion-machine-learning.png",width = 500, height = 300)

# %%
Image("sesgo_varianza.png",width = 600, height = 400)

# %%
Image("overfitting-and-underfitting-wrt-model-error-vs-complexity-768x443.png",width = 400, height = 400)

# %% [markdown]
# # Normalización (evitar el sobre ajuste)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes

# %%
exploraty = load_diabetes(as_frame=True,return_X_y=True)[0]
exploraty

# %%
target = load_diabetes(as_frame=True,return_X_y=True)[1]
target

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X=exploraty, y=target)

# %%
model.predict(exploraty)

# %%
from sklearn.linear_model import Lasso

# %%
norma_l1 = Lasso()

# %%
norma_l1.fit(exploraty,target)

# %%
norma_l1.coef_

# %%
lasso_predict = norma_l1.predict(exploraty)

# %%
predict = model.predict(exploraty)

# %%
df_resultados = pd.DataFrame({"lasso_predict":lasso_predict, "predict": predict})

# %%
df_resultados

# %%
df_total = exploraty

# %%
df_total["traget"] = target

# %%
df_total["predict"] = predict

# %%
df_total["lasso_predict"] = lasso_predict

# %%
df_total

# %%
df_total.columns

# %%
variables_explicativas = df_total.drop(columns=['traget',
       'predict', 'lasso_predict'])

# %%
import seaborn as sns

# %%
df_total["predict"]

# %%
sns.scatterplot(x=df_total["traget"], y = df_total["predict"])
sns.scatterplot(x=df_total["traget"], y = df_total["lasso_predict"])
sns.scatterplot(x=df_total["traget"], y = df_total["traget"])

# %%
rng = np.random.RandomState(42)
n_random_features = 14
X_random = pd.DataFrame(
    rng.randn(X.shape[0], n_random_features),
    columns=[f"random_{i:02d}" for i in range(n_random_features)],
)
X = pd.concat([X, X_random], axis=1)
# Show only a subset of the columns
X[X.columns[::3]].head()

# %% [markdown]
# # Regesión Logística

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

from sklearn import datasets

# %%
datos_cancer = datasets.load_breast_cancer()

# %%
datos_cancer.keys()

# %%
datos_cancer.data.shape

# %%
df_cancer = pd.DataFrame(data=datos_cancer.data, columns=datos_cancer.feature_names)
df_cancer["objetivo"] = datos_cancer.target

# %%
df_cancer

# %%
exploraty =datos_cancer.data

# %%
target = datos_cancer.target

# %%
from IPython.display import Image
Image("train_test.png",width=700)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
model_lr = LinearRegression()

# %%
X_train, X_test, y_train, y_test  = train_test_split(exploraty,target)

# %%
print("exploraty",exploraty.shape)
print("target",target.shape)

# %%
print("X_train",X_train.shape)
print("X_test",X_test.shape)
print("y_train",y_train.shape) 
print("y_test",y_test.shape)

# %%
from sklearn.linear_model import LinearRegression
# dividimos los datos en de entrenamiento

model_lr.fit(X= X_train, y= y_train)

# %%
# Entrenamos el modelo dividir los datos
model_lr.fit(X=df_cancer.drop(columns=["objetivo"]), y = df_cancer.objetivo)

# %%
model_lr.predict(X= X_train)

# %%
model_lr.score(X=X_train, y=y_train)

# %%
model_lr.score(X=X_test, y=y_test)

# %% [markdown]
# # Pipelines en scikit-learn

# %% [markdown]
# # ipywidgets
# >

# %%
# No sé que version instalé de ipywidgets

# %%
from ipywidgets import widgets, interact
import numpy as np

# %%
import seaborn as sns

cars = sns.load_dataset("mpg")[:]
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
# FIJO
sns.scatterplot(x= cars.mpg, y=cars.acceleration);

# %% [markdown]
# #### Vamos hacer un gráfico interativo a través de ipywidgets

# %%
def grafico(n_casos):
    cars = sns.load_dataset("mpg")[:n_casos]
    sns.scatterplot(x= cars.mpg, y=cars.acceleration,hue_norm=1)

# %%
interact(grafico, n_casos=(0,10000));
# Out:
# interactive(children=(IntSlider(value=5000, description='n_casos', max=10000), Output()), _dom_classes=('widge…

# %%
text= [0,1,2,3]
for i in text:
    print("Hello {}".format(text[i]))
# Out:
# Hello 0
# Hello 1
# Hello 2
# Hello 3

# %% [markdown]
# #

# %% [markdown]
# #### Ejemplo de como funciona interact
#  > 1º Definimos def__
#
#  > 2º interact(nombre_def, paremetro=(a,b))

# %%
def f(x,y):
    return x+y

# %%
interact(f, x=(0,10), y=(0,100));
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=10), IntSlider(value=50, description='y'), Outpu…

# %%
from ipywidgets import widgets, interact
import numpy as np

# %%
def prueba(coste_a, coste_b):
    return np.exp(coste_a)/(np.exp(coste_b)+np.exp(coste_a))

# %%
@interact
def calculo_umbral(
    coste_a = widgets.FloatSlider(min= 1,max=10, step=0.1,value= 1),
    coste_b = widgets.FloatSlider(min= 1,max=10, step=0.1,value= 1),
):
    return prueba(coste_a,coste_b)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='coste_a', max=10.0, min=1.0), FloatSlider(value=1.0,…

# %%
def restar(x,y):
    return print("Resta (x-y) =",x-y)

# %%
interact(restar,x=(1,10),y=(1,10));
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=10, min=1), IntSlider(value=5, description='y', …

# %%
import numpy as np
import random

# %%
random.randint(1,10)
print(i*random.randint(1,10))
# Out:
# 2

# %%
lista_premio= []

# %%
for i in range(5):
    lista_premio.append(i*random.randint(5000,1000000))

# %%
lista_premio
# Out:
# [0, 780266, 207460, 1478871, 3567104, 0, 0, 699148, 194702, 226722, 1616088]

# %%
sum(lista_premio)
# Out:
# 8770361

# %%
def reparto(n):
    return (sum(lista_premio))/n

# %%
interact(reparto,n=(1,3));
# Out:
# interactive(children=(IntSlider(value=2, description='n', max=3, min=1), Output()), _dom_classes=('widget-inte…
